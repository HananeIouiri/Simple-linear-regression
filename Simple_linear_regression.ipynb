# %% [markdown]
# <a href="https://colab.research.google.com/github/HananeIouiri/Simple-linear-regression/blob/main/Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Import the dataset
Data = pd.read_csv('Advertising.csv')

# %%
Data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
# Display a scatter plot (TV vs Sales)
plt.scatter(Data['TV'], Data['Sales'])
plt.xlabel('TV Advertising Budget')  # Add label for x-axis
plt.ylabel('Sales')  # Add label for y-axis
plt.title('TV vs Sales (Before Filtering)')  # Add title
plt.show()

# %%
# Exclude data where Sales > 25
Data = Data[Data['Sales'] < 25]

# %%
# Display the filtered scatter plot
plt.scatter(Data['TV'], Data['Sales'], color='red')
plt.xlabel('TV Advertising Budget')
plt.ylabel('Sales')
plt.title('TV vs Sales (After Filtering)')
plt.show()

# %%
# Define feature (TV) and target (Sales) for simple linear regression
X = Data[['TV']].values  # Feature: Select only the 'TV' column (2D array for sklearn)
Y = Data['Sales'].values  # Target: Sales column

# %%
X
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
# ...

# %%
Y
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 13.2,
#        17.4, 11.9, 17.8, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 17.9,  8.5,
#        16.1, 10.6, 23.2, 19.8,  9.7, 16.4, 10.7, 22.6, 21.2, 20.2, 23.7,
#         5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 20.7, 14. , 16. , 11.3, 11. ,
#        13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9, 14.2,
#         5.3, 11. , 11.8, 17.3, 11.3, 13.6, 21.7, 20.2, 12. , 16. , 12.9,
#        16.7, 14. ,  7.3, 19.4, 22.2, 11.5, 16.9, 16.7, 20.5, 17.2, 16.7,
#        23.8, 19.8, 19.7, 20.7, 15. ,  7.2, 12. ,  5.3, 19.8, 18.4, 21.8,
#        17.1, 20.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,  7. , 16.6,
#        15.2, 19.7, 10.6,  6.6, 11.9, 24.7,  9.7,  1.6, 17.7,  5.7, 19.6,
#        10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1, 10.4, 12.3,
# ...

# %%
# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, Y_train)  # Fit the model on training data
# Out:
# LinearRegression()

# %%
# Make predictions
Y_pred = model.predict(X_test)  # Predict Sales for the test

# %%
Y_pred
# Out:
# array([11.24688077,  8.22794813, 14.51739113, 14.4156895 ,  8.50093672,
#         9.53401119, 10.93107044, 11.51986936,  8.18512639, 13.66095634,
#         7.69267639, 11.89455958, 15.97868299, 16.09109006,  8.13159922,
#        21.4438075 , 15.60934549, 18.20006073, 17.45603301,  8.66151825,
#        17.80395964,  7.85325791, 18.92267759, 19.31342596, 18.99226291,
#        20.81218685, 10.23521717, 12.02837752,  7.93354867, 15.2453607 ,
#        19.13143357, 16.59959822, 19.51147651, 16.90470311, 20.03604282,
#        19.65064716, 20.65695804,  8.27612259, 14.8760232 ])

# %%
Y_test
# Out:
# array([12.6,  6.7, 13.2, 14. ,  9.2, 10.1, 11.3, 11.9,  8. , 13.2,  7.2,
#        10.6, 18. , 17.6,  8.7, 17.4, 15.5, 22.6, 17.3,  8.8, 16.6,  7.3,
#        17.2, 18.4, 19.6, 17.6,  8.7, 10.6,  5.6, 10.1, 16.7, 16.1, 19.7,
#        17.9, 20.7, 18.4, 22.2,  7.6, 15. ])

# %%
model.predict([[300]])
# Out:
# array([23.28514231])

# %%
# Display the slope (coefficient) and intercept
print("Slope (coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (coefficient): 0.05352717444886897
# Intercept: 7.226989970870973

# %%
# Plot the regression line with the test data
plt.scatter(X_test, Y_test, color='blue', label='Actual Sales')
plt.plot(X_test, Y_pred, color='red', label='Regression Line')
plt.xlabel('TV Advertising Budget')
plt.ylabel('Sales')
plt.title('Simple Linear Regression: TV vs Sales')
plt.legend()
plt.show()
